# %%
from fdip import FDIP

# %% [markdown]
# We read in the filtered data file generated by the first script.

# %%
p = FDIP("slagheap_corr")
print(p)
# Out:
# 17/08/26 - 07:23:21 - pyGIMLi - INFO - filtering: nd=696, nf=9
# 17/08/26 - 07:23:21 - pyGIMLi - INFO - Sum(ind): 696
# 17/08/26 - 07:23:21 - pyGIMLi - INFO - filtered: nd=696, nf=9
# SIP data: nf=9 nc=0 nv=59 Data: Sensors: 40 data: 696, nonzero entries: ['a', 'b', 'k', 'm', 'n', 'valid']

# %%
p.simultaneousInversion(verbose=True, scaleF=0.2)
# Out:
# 17/08/26 - 07:23:21 - pyGIMLi - INFO - Found 2 regions.
# 17/08/26 - 07:23:21 - pyGIMLi - INFO - Region with smallest marker set to background (marker=1)
# 17/08/26 - 07:23:21 - pyGIMLi - INFO - Found 2 regions.
# 17/08/26 - 07:23:21 - pyGIMLi - INFO - Region with smallest marker set to background (marker=1)
# 17/08/26 - 07:23:21 - pyGIMLi - INFO - Found 2 regions.
# 17/08/26 - 07:23:21 - pyGIMLi - INFO - Region with smallest marker set to background (marker=1)
# 17/08/26 - 07:23:21 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 17/08/26 - 07:23:21 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 17/08/26 - 07:23:21 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 3279 Cells: 6208 Boundaries: 4830
# 17/08/26 - 07:23:22 - pyGIMLi - INFO - Starting inversion.
# 17/08/26 - 07:23:22 - pyGIMLi - INFO - fop: <pygimli.frameworks.timelapse.MultiFrameModelling object at 0x00000209E999E6B0>
# ...

# %%
p.fitAllRhoPhi();

# %%
p.showColeColeParameters(rlim=(100, 500), mlim=(0, 1), tlim=(0.1, 100),
                         coverage=1);

# %%
p.saveResults()
